# %%
## 서울 열린데이터 광장

# %%
import requests
import json
import pandas as pd
SERVICE_KEY = 'your_key'
url = f'http://openapi.seoul.go.kr:8088/{SERVICE_KEY}/json/tbLnOpendataRtmsV/1/1000/2022/11560'
req = requests.get(url)

# %%
content = req.json()
result = pd.DataFrame(content['tbLnOpendataRtmsV']['row'])
result
# Out:
#     ACC_YEAR SGG_CD SGG_NM BJDONG_CD BJDONG_NM LAND_GBN LAND_GBN_NM BONBEON  \
# 0       2022  11560   영등포구     12100     문래동3가        1          대지    0077
# 1       2022  11560   영등포구     11800       도림동        1          대지    0152
# 2       2022  11560   영등포구     13200       신길동        1          대지    0022
# 3       2022  11560   영등포구     10500    영등포동4가        1          대지    0103
# 4       2022  11560   영등포구     13300       대림동        1          대지    1075
# ..       ...    ...    ...       ...       ...      ...         ...     ...
# 995     2022  11560   영등포구     10200    영등포동1가        1          대지    0094
# 996     2022  11560   영등포구     10200    영등포동1가        1          대지    0094
# 997     2022  11560   영등포구     11000      여의도동        1          대지    0012
# 998     2022  11560   영등포구     13300       대림동        1          대지    1101
# 999     2022  11560   영등포구     11000      여의도동        1          대지    0061
#
#     BUBEON              BLDG_NM  ... OBJ_AMT BLDG_AREA  TOT_AREA  FLOOR  \
# 0     0010               문래역 이안  ...   85000     96.68    112.96    6.0
# 1     0006              (152-6)  ...   39000     84.74     45.17    4.0
# 2     0005      대우 디오빌 골든뷰 오피스텔  ...   16000     28.29     37.79    8.0
# 3     0000          영등포 대성 그랑그루  ...   12500     16.69     22.53    2.0
# 4     0083                대림하이츠  ...   40450     40.88     24.88    2.0
# ..     ...                  ...  ...     ...       ...       ...    ...
# 995   0002            여의도더리브스타일  ...   20800     19.36     30.80    5.0
# 996   0002            여의도더리브스타일  ...   20800     19.36     30.80    5.0
# 997   0003  (주)신한 여의도 드림리버 오피스텔  ...   28800     24.50     36.70   13.0
# 998   0007                G밸리소홈  ...   14500     16.10      0.00    7.0
# 999   0004                 콤비빌딩  ...   20000     50.02     56.23    8.0
#
#      RIGHT_GBN CNTL_YMD BUILD_YEAR HOUSE_TYPE REQ_GBN   RDEALER_LAWDNM
# 0                             2004       오피스텔     직거래
# 1                             2003      연립다세대    중개거래          서울 영등포구
# 2                             2004       오피스텔     직거래
# 3                             2012       오피스텔    중개거래           서울 마포구
# 4                             2022      연립다세대     직거래
# ..         ...      ...        ...        ...     ...              ...
# 995                           2020       오피스텔    중개거래          서울 영등포구
# 996                           2020       오피스텔    중개거래          서울 영등포구
# 997                           2019       오피스텔    중개거래  서울 마포구, 서울 영등포구
# 998                           2018        아파트    중개거래            인천 서구
# 999                           1994       오피스텔    중개거래          서울 영등포구
#
# [1000 rows x 21 columns]

# %%
import requests
import json
import pandas as pd

SERVICE_KEY = 'your_key'

data_list = []

for start_idx in range(1, 12001, 1000):
    end_idx = min(start_idx + 999, 12000)
    url = f'http://openapi.seoul.go.kr:8088/{SERVICE_KEY}/json/tbLnOpendataRtmsV/{start_idx}/{end_idx}/2022/11680'
    content = requests.get(url).json()
    data_list.extend(content.get('tbLnOpendataRtmsV', {}).get('row', []))

result = pd.DataFrame(data_list)
print(result)
# Out:
#       ACC_YEAR SGG_CD SGG_NM BJDONG_CD BJDONG_NM LAND_GBN LAND_GBN_NM BONBEON  \
# 0         2022  11680    강남구     10300       개포동        1          대지    1165
# 1         2022  11680    강남구     10300       개포동        1          대지    0189
# 2         2022  11680    강남구     10100       역삼동        1          대지    0656
# 3         2022  11680    강남구     10800       논현동        1          대지    0209
# 4         2022  11680    강남구     10100       역삼동        1          대지    0720
# ...        ...    ...    ...       ...       ...      ...         ...     ...
# 11875     2022  11680    강남구     10300       개포동        1          대지    1237
# 11876     2022  11680    강남구     10300       개포동        1          대지    1198
# 11877     2022  11680    강남구     10300       개포동        1          대지    1198
# 11878     2022  11680    강남구     10300       개포동        1          대지    1198
# 11879     2022  11680    강남구     10300       개포동        1          대지    1198
#
#       BUBEON    BLDG_NM  ... OBJ_AMT BLDG_AREA  TOT_AREA  FLOOR  RIGHT_GBN  \
# 0       0016     칠성빌라나동  ...   69000     50.28     41.77    1.0
# 1       0000  개포프레지던스자이  ...  200000     84.60      0.00    2.0        입주권
# 2       0030    역삼엔스위트1  ...   70000     90.15      0.00    7.0
# 3       0000  삼환 아르누보 3  ...   23700     22.09     29.71    7.0
# 4       0025      대우디오빌  ...   32000     39.13      0.00   15.0
# ...      ...        ...  ...     ...       ...       ...    ...        ...
# 11875   0008      YH빌리지  ...   40000     31.47     39.38    2.0
# 11876   0004     운영빌라5차  ...   10000     30.07     13.20   -1.0
# 11877   0004     운영빌라5차  ...   10000     30.07     13.20   -1.0
# 11878   0004     운영빌라5차  ...   10000     30.07     13.20   -1.0
# 11879   0004     운영빌라5차  ...   10000     30.07     13.20   -1.0
#
#        CNTL_YMD BUILD_YEAR HOUSE_TYPE REQ_GBN RDEALER_LAWDNM
# 0                     1989      연립다세대    중개거래         서울 강남구
# 1                        0        아파트    중개거래         서울 강남구
# 2      20230103       2005        아파트     직거래
# 3                     2005       오피스텔    중개거래         서울 강남구
# 4                     2002        아파트    중개거래         서울 강남구
# ...         ...        ...        ...     ...            ...
# 11875                 2017       오피스텔
# 11876  20220520       1997      연립다세대
# 11877  20220520       1997      연립다세대
# 11878  20220520       1997      연립다세대
# 11879  20220520       1997      연립다세대
#
# [11880 rows x 21 columns]
