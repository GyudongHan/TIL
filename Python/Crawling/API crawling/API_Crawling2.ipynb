# %% [markdown]
# 공공데이터 포털

# %%
# XML 이용하여 데이터 불러오기
import requests
import pandas as pd 

serviceKey = 'UV78PReRPsOQOiDb2SzFsBjoDL1oUJVjKWg91kjVXpgcAJYaUOCY7f7WGG%2FgWTW7K7aLLdexwZUb7el%2Fhv1R8A%3D%3D'
pageNo = 1 # 페이지 번호
numOfRows = 1000 # 한 페이지 결과수
LAWD_CD = 11560 # 지역코드
DEAL_YMD = 202307 # 계약월
url = f'http://openapi.molit.go.kr/OpenAPI_ToolInstallPackage/service/rest/RTMSOBJSvc/getRTMSDataSvcAptTradeDev?serviceKey={serviceKey}&pageNo={pageNo}&numOfRows=10&LAWD_CD={LAWD_CD}&DEAL_YMD={DEAL_YMD}'
req = requests.get(url)
req.text
# Out:
# '<?xml version="1.0" encoding="UTF-8" standalone="yes"?><response><header><resultCode>00</resultCode><resultMsg>NORMAL SERVICE.</resultMsg></header><body><items><item><거래금액>    45,300</거래금액><거래유형>중개거래</거래유형><건축년도>2021</건축년도><년>2023</년><도로명>신길로61길</도로명><도로명건물본번호코드>00028</도로명건물본번호코드><도로명건물부번호코드>00000</도로명건물부번호코드><도로명시군구코드>11560</도로명시군구코드><도로명일련번호코드>00</도로명일련번호코드><도로명코드>4154554</도로명코드><등기일자> </등기일자><법정동> 영등포동</법정동><법정동본번코드>0651</법정동본번코드><법정동부번코드>0000</법정동부번코드><법정동시군구코드>11560</법정동시군구코드><법정동읍면동코드>10100</법정동읍면동코드><법정동지번코드>1</법정동지번코드><아파트>라르파크</아파트><월>7</월><일>29</일><일련번호>11560-2213</일련번호><전용면적>30.7084</전용면적><중개사소재지>서울 영등포구</중개사소재지><지번>651</지번><지역코드>11560</지역코드><층>2</층><해제사유발생일> </해제사유발생일><해제여부> </해제여부></item><item><거래금액>    41,700</거래금액><거래유형>중개거래</거래유형><건축년도>2020</건축년도><년>2023</년><도로명>경인로</도로명><도로명건물본번호코드>00900</도로명건물본번호코드><도로명건물부번호코드>00000</도로명건물부번호코드><도로명시군구코드>11560</도로명시군구코드><도로명일련번호코드>00</도로명일련번호코드><도로명코드>3000028</도로명코드><등기일자> </등기일자><법정동> 영등포동1가</법정동><법정동본번코드>0094</법정동본번코드><법정동부번코드>0002</법정동부번코드><법정동시군구코드>11560</법정동시군구코드><법정동읍면동코드>10200</법정동읍면동코드><법정동지번코드>1</법정동지번코드><아파트>여의도더리브스타일</아파트><월>7</월><일>1</일><일련번호>11560-2153</일련번호><전용면적>30.2696</전용면적><중개사소재지>서울 영등포구</중개사소재지><지번>94-2</지번><지역코드>11560</지역코드><층>3</층><해제사유발생일> </해제사유발생일><해제여부> </해제여부></item><item><거래금액>    30,500</거래금액><거래유형>직거래</거래유형><건축년도>2022</건축년도><년>2023</년><도로명>경인로114길</도로명><도로명건물본번호코드>00006</도로명건물본번호코드><도로명건물부번호코드>00000</도로명건물부번호코드><도로명시군구코드>11560</도로명시군구코드><도로명일련번호코드>00</도로명일련번호코드><도로명지상지하코드>0</도로명지상지하코드><도로명코드>4154044</도로명코드><등기일자>23.08.01</등기일자><법정동> 영등포동1가</법정동><법정동본번코드>0092</법정동본번코드><법정동부번코드>0003</법정동부번코드><법정동시군구코드>11560</법정동시군구코드><법정동읍면동코드>10200</법정동읍면동코드><법정동지번코드>1</법정동지번코드><아파트>여의도이튼브라운</아파트><월>7</월><일>31</일><일련번호>11560-2281</일련번호><전용면적>31.19</전용면적><중개사소재지> </중개사소재지><지번>92-3</지번><지역코드>11560</지역코드><층>5</층><해제사유발생일> </해제사유발생일><해제여부> </해제여부></item><item><거래금액>    62,260</거래금액><거래유형>중개거래</거래유형><건축년도>2022</건축년도><년>2023</년><도로명>버드나루로</도로명><도로명건물본번호코드>00005</도로명건물본번호코드><도로명건물부번호코드>00000</도로명건물부번호코드><도로명시군구코드>11560</도로명시군구코드><도로명일련번호코드>00</도로명일련번호코드><도로명지상지하코드>0</도로명지상지하코드><도로명코드>3118010</도로명코드><등기일자> </등기일자><법정동> 영등포동2가</법정동><법정동본번코드>0139</법정동본번코드><법정동부번코드>0000</법정동부번코드><법정동시군구코드>11560</법정동시군구코드><법정동읍면동코드>10300</법정동읍면동코드><법정동지번코드>1</법정동지번코드><아파트>여의도리미티오148</아파트><월>7</월><일>17</일><일련번호>11560-2270</일련번호><전용면적>38.441</전용면적><중개사소재지>서울 영등포구</중개사소재지><지번>139</지번><지역코드>11560</지역코드><층>8</층><해제사유발생일>23.08.01</해제사유발생일><해제여부>O</해제여부></item><item><거래금액>    62,260</거래금액><거래유형>중개거래</거래유형><건축년도>2022</건축년도><년>2023</년><도로명>버드나루로</도로명><도로명건물본번호코드>00005</도로명건물본번호코드><도로명건물부번호코드>00000</도로명건물부번호코드><도로명시군구코드>11560</도로명시군구코드><도로명일련번호코드>00</도로명일련번호코드><도로명지상지하코드>0</도로명지상지하코드><도로명코드>3118010</도로명코드><등기일자> </등기일자><법정동> 영등포동2가</법정동><법정동본번코드>0139</법정동본번코드><법정동부번코드>0000</법정동부번코드><법정동시군구코드>11560</법정동시군구코드><법정동읍면동코드>10300</법정동읍면동코드><법정동지번코드>1</법정동지번코드><아파트>여의도리미티오148</아파트><월>7</월><일>17</일><일련번호>11560-2270</일련번호><전용면적>38.441</전용면적><중개사소재지>서울 영등포구</중개사소재지><지번>139</지번><지역코드>11560</지역코드><층>8</층><해제사유발생일> </해제사유발생일><해제여부> </해제여부></item><item><거래금액>    10,400</거래금액><거래유형>중개거래</거래유형><건축년도>2014</건축년도><년>2023</년><도로명>영중로6길</도로명><도로명건물본번호코드>00012</도로명건물본번호코드><도로명건물부번호코드>00000</도로명건물부번호코드><도로명시군구코드>11560</도로명시군구코드><도로명일련번호코드>01</도로명일련번호코드><도로명지상지하코드>0</도로명지상지하코드><도로명코드>4154816</도로명코드><등기일자> </등기일자><법정동> 영등포동3가</법정동><법정동본번코드>0019</법정동본번코드><법정동부번코드>0002</법정동부번코드><법정동시군구코드>11560</법정동시군구코드><법정동읍면동코드>10400</법정동읍면동코드><법정동지번코드>1</법정동지번코드><아파트>포레스트힐시티</아파트><월>7</월><일>7</일><일련번호>11560-1680</일련번호><전용면적>13.53</전용면적><중개사소재지>서울 영등포구</중개사소재지><지번>19-2</지번><지역코드>11560</지역코드><층>7</층><해제사유발생일> </해제사유발생일><해제여부> </해제여부></item><item><거래금액>   145,700</거래금액><거래유형>중개거래</거래유형><건축년도>2017</건축년도><년>2023</년><도로명>국회대로54길</도로명><도로명건물본번호코드>00010</도로명건물본번호코드><도로명건물부번호코드>00000</도로명건물부번호코드><도로명시군구코드>11560</도로명시군구코드><도로명일련번호코드>00</도로명일련번호코드><도로명코드>4154084</도로명코드><등기일자> </등기일자><법정동> 영등포동7가</법정동><법정동본번코드>0203</법정동본번코드><법정동부번코드>0000</법정동부번코드><법정동시군구코드>11560</법정동시군구코드><법정동읍면동코드>10800</법정동읍면동코드><법정동지번코드>1</법정동지번코드><아파트>아크로타워스퀘어</아파트><월>7</월><일>4</일><일 ...

# %%
pip install xmltodict
# Out:
# Requirement already satisfied: xmltodict in c:\users\user\desktop\multicampus28\venv\lib\site-packages (0.13.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %%timeit

import xmltodict
import pandas as pd

data_dict = xmltodict.parse(req.text)
pd.DataFrame(data_dict['response']['body']['items']['item'])
# Out:
#       거래금액  거래유형  건축년도     년        도로명 도로명건물본번호코드 도로명건물부번호코드 도로명시군구코드  \
# 0   45,300  중개거래  2021  2023     신길로61길      00028      00000    11560
# 1   41,700  중개거래  2020  2023        경인로      00900      00000    11560
# 2   30,500   직거래  2022  2023    경인로114길      00006      00000    11560
# 3   62,260  중개거래  2022  2023      버드나루로      00005      00000    11560
# 4   62,260  중개거래  2022  2023      버드나루로      00005      00000    11560
# 5   10,400  중개거래  2014  2023      영중로6길      00012      00000    11560
# 6  145,700  중개거래  2017  2023    국회대로54길      00010      00000    11560
# 7  145,000  중개거래  2017  2023    국회대로54길      00010      00000    11560
# 8  120,000  중개거래  2017  2023    국회대로54길      00010      00000    11560
# 9   84,000  중개거래  2004  2023  버드나루로12가길      00013      00000    11560
#
#   도로명일련번호코드    도로명코드  ...   일        일련번호     전용면적           중개사소재지    지번  \
# 0        00  4154554  ...  29  11560-2213  30.7084          서울 영등포구   651
# 1        00  3000028  ...   1  11560-2153  30.2696          서울 영등포구  94-2
# 2        00  4154044  ...  31  11560-2281    31.19             None  92-3
# 3        00  3118010  ...  17  11560-2270   38.441          서울 영등포구   139
# 4        00  3118010  ...  17  11560-2270   38.441          서울 영등포구   139
# 5        01  4154816  ...   7  11560-1680    13.53          서울 영등포구  19-2
# 6        00  4154084  ...   4  11560-1955    84.75          서울 영등포구   203
# 7        00  4154084  ...   6  11560-1955    84.75          서울 영등포구   203
# 8        00  4154084  ...   6  11560-1955    59.91  서울 송파구, 서울 영등포구   203
# 9        02  4154410  ...  14   11560-151     84.9          서울 영등포구   202
#
#     지역코드   층   해제사유발생일  해제여부 도로명지상지하코드
# 0  11560   2      None  None       NaN
# 1  11560   3      None  None       NaN
# 2  11560   5      None  None         0
# 3  11560   8  23.08.01     O         0
# 4  11560   8      None  None         0
# 5  11560   7      None  None         0
# 6  11560  12      None  None       NaN
# 7  11560  11      None  None       NaN
# 8  11560  13      None  None       NaN
# 9  11560  14      None  None         0
#
# [10 rows x 29 columns]

# %%
# %%timeit

import requests
import pandas as pd 
import xmltodict

serviceKey = 'UV78PReRPsOQOiDb2SzFsBjoDL1oUJVjKWg91kjVXpgcAJYaUOCY7f7WGG%2FgWTW7K7aLLdexwZUb7el%2Fhv1R8A%3D%3D'
pageNo = 1 # 페이지 번호
numOfRows = 1000 # 한 페이지 결과수
LAWD_CD = 11560 # 지역코드
DEAL_YMD = 202307 # 계약월
url = f'http://openapi.molit.go.kr/OpenAPI_ToolInstallPackage/service/rest/RTMSOBJSvc/getRTMSDataSvcAptTradeDev?serviceKey={serviceKey}&pageNo={pageNo}&numOfRows=10&LAWD_CD={LAWD_CD}&DEAL_YMD={DEAL_YMD}'
req = requests.get(url)
# req.text
data_dict = xmltodict.parse(req.text)
# data_dict 확인함
pd.DataFrame(data_dict['response']['body']['items']['item'])
# Out:
#       거래금액  거래유형  건축년도     년        도로명 도로명건물본번호코드 도로명건물부번호코드 도로명시군구코드  \
# 0   45,300  중개거래  2021  2023     신길로61길      00028      00000    11560
# 1   41,700  중개거래  2020  2023        경인로      00900      00000    11560
# 2   30,500   직거래  2022  2023    경인로114길      00006      00000    11560
# 3   62,260  중개거래  2022  2023      버드나루로      00005      00000    11560
# 4   62,260  중개거래  2022  2023      버드나루로      00005      00000    11560
# 5   10,400  중개거래  2014  2023      영중로6길      00012      00000    11560
# 6  145,700  중개거래  2017  2023    국회대로54길      00010      00000    11560
# 7  145,000  중개거래  2017  2023    국회대로54길      00010      00000    11560
# 8  120,000  중개거래  2017  2023    국회대로54길      00010      00000    11560
# 9   84,000  중개거래  2004  2023  버드나루로12가길      00013      00000    11560
#
#   도로명일련번호코드    도로명코드  ...   일        일련번호     전용면적           중개사소재지    지번  \
# 0        00  4154554  ...  29  11560-2213  30.7084          서울 영등포구   651
# 1        00  3000028  ...   1  11560-2153  30.2696          서울 영등포구  94-2
# 2        00  4154044  ...  31  11560-2281    31.19             None  92-3
# 3        00  3118010  ...  17  11560-2270   38.441          서울 영등포구   139
# 4        00  3118010  ...  17  11560-2270   38.441          서울 영등포구   139
# 5        01  4154816  ...   7  11560-1680    13.53          서울 영등포구  19-2
# 6        00  4154084  ...   4  11560-1955    84.75          서울 영등포구   203
# 7        00  4154084  ...   6  11560-1955    84.75          서울 영등포구   203
# 8        00  4154084  ...   6  11560-1955    59.91  서울 송파구, 서울 영등포구   203
# 9        02  4154410  ...  14   11560-151     84.9          서울 영등포구   202
#
#     지역코드   층   해제사유발생일  해제여부 도로명지상지하코드
# 0  11560   2      None  None       NaN
# 1  11560   3      None  None       NaN
# 2  11560   5      None  None         0
# 3  11560   8  23.08.01     O         0
# 4  11560   8      None  None         0
# 5  11560   7      None  None         0
# 6  11560  12      None  None       NaN
# 7  11560  11      None  None       NaN
# 8  11560  13      None  None       NaN
# 9  11560  14      None  None         0
#
# [10 rows x 29 columns]
